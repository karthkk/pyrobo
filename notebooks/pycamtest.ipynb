# %%
import pylibcam

# %%
cam_1 = pylibcam.PyCamera('/dev/video0', 640, 480, 5)
cam_2 = pylibcam.PyCamera('/dev/video1', 640, 480, 5)

# %%
import time
cam_1.setBrightness(1)
cam_2.setBrightness(1)
for i in range(4):
    time.sleep(2)
    cam_1.update(25,1000)
    cam_2.update(25,1000)
cam_1.update(25,1000)
cam_2.update(25,1000)
img_1 = cam_1.toRGB()
img_2 = cam_2.toRGB()

# %%
# %matplotlib notebook

# %%
from matplotlib im   
port pyplot as pl
import numpy as np

# %%
img = np.zeros((480, 640*2, 3), dtype=img_1.dtype)
img[:,:640,:] = img_1
img[:,640:,:] = img_2
pl.imshow(img)
# Out:
# <img src="data:image/png;base64,...">

# %%
cam_1.StopCam()
cam_2.StopCam()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6677022061c8> in <module>()
# ----> 1 cam_1.StopCam()
#       2 cam_2.StopCam()
#
# NameError: name 'cam_1' is not defined
